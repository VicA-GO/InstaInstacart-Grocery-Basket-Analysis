# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Task

# %% [markdown]
# ### 3.  Import the orders_products_combined dataframe from the pickle file

# %%
path = r'C:\Users\Víctor A\Desktop\CAREER FOUNDRY\Instacart Basket Analysis'

# %%
# First, importing 'products_checked.csv'

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Second, importing 'orders_products_combined'

df_ords_prodsp = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ### 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
df_ords_prodsp.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ### 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set.

# %%
df_ords_prodsp
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_last_order  is_first_order  \
# 0                         8                    0.0            True
# 1                         8                    0.0            True
# ...

# %%
# Dropping column '_merge' from df_prodsp

df_ords_prodsp = df_ords_prodsp.drop(columns = ['_merge'])

# %%
# Merging df_prods and df_ords_prodsp

df_merged = df_prods.merge(df_ords_prodsp, on = 'product_id', indicator = True)

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %%
df_merged.shape
# Out:
# (32404859, 15)

# %% [markdown]
# ### 6. Confirm the results of the merge using the merge flag.

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Export the newly created dataframe as ords_prods_merge in a suitable format (taking into consideration the size).

# %%
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
